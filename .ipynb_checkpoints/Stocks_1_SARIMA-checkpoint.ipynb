# %% [markdown]
# # Stocks 1 - Time-Series (SARIMA)

# %% [markdown]
# ---
# <div style="text-align: right"> Author: Vassil Dimitrov </div>
# <div style="text-align: right"> Date: 2023-08-04 </div>

# %% [markdown]
# A simple SARIMAX model will be trained to predict the close value of the stock at the end of each day.

# %% [markdown]
# ## Prep

# %% [markdown]
# ### Load libraries

# %% [markdown]
# Load all necessary libraries.

# %%
# Stats:
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from math import sqrt

# System:
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings

# plotting
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go

# %% [markdown]
# ### Load Data

# %%
df = pd.read_pickle('df_clean_2020.pkl')

# %% [markdown]
# ## Autocorrelation & Partial Autocorrelation

# %% [markdown]
# An autocorrelation and partial autocorrelation plots will be graphed in order to determine approximate starting values for the various components of the SARIMA time series model.

# %%
lags = 60

# Create ACF and PACF plots
fig, ax = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(df['close'].dropna(), lags=lags, ax=ax[0])
plot_pacf(df['close'].dropna(), lags=lags, ax=ax[1])

# Show the plots
plt.show()

# %% [markdown]
# <a id="parameters"></a>The autocorrelation plot shows that the values decrease monotonically to become insignificant past lag 48. This implies that information for current values can be gained from values of the past 48 days (approximately 7 weeks).
#
# The partial autocorrelation plot shows an almost perfect correlation with lag1 with several interspersed correlations at lag 10, lag 18, lag 24, lag 25, lag 33, lag 48, lag 49 and lag 56. These small positive and negative correlations indicate the potential presence of a moving average (MA) component. The partial autocorrelation also indicates the presence of a seasonal component. The component was very clearly depicted by the SEASONAL plot from the component decomposition above and shows a clear weekly cycle following essentially identical trend.
#
# Based on the observations above, a good starting point for a model optimization is the following:
# - `p` = 1
#     - autoregressive order of 1 since the partial autocorrelation is very significant at lag 1
# - `q` = 0
#     - EXPLORE!
#     - It does not seem like one needs to obtain a moving average in order to model the daily data and the weekly seasonal trend.
# - `d` = 0
#     - I have daily data that is not differenced so differencing will not be required here
#
#
# Importantly, since there are multiple seasonal patterns -- weekly and monthly are the most interesting in this particular case -- SARIMA algorithms will be quite useful to model multiple patterns in the data.
#
# For a SARIMA model, the following parameters can be used:
# - S = 5 (seasonal period)
#     - Also try S = 20 for monthly seasonal trend
# - P = 1 (autoregressive order)
# - Q = ? (moving average)
#     - EXPLORE!
# - D = ? (differencing)
#     - EXPLORE!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>NB!:</b> Note that the trend is none of the following: no trend, constant, linear, constant and linear. Nevertheless, this model will be assessed. Based on the trend, it may be more appropriate to employ Grid Search on Triple Exponential Smoothing for Time Series Forecasting as described below.
# </div>

# %% [markdown]
# ***[Grid Search on Triple Exponential Smoothing for Time Series Forecasting](https://machinelearningmastery.com/how-to-grid-search-triple-exponential-smoothing-for-time-series-forecasting-in-python/)***

# %% [markdown]
# ## Model Fit

# %% [markdown]
# A model will now be fit and tested using the SARIMA model. Various values for the SARIMA hyperparameters will be tested in order to select the optimal model. A grid search for the best set of parameters will be performed.

# %% [markdown]
# ### Training and Testing

# %% [markdown]
# An approach using a walk-forward validation will be used to optimize the hyperparameters for the model. To assess the performance of the model, a new test set will be obtained from incoming new market values, which is the definition of model testing on unseen data.

# %% [markdown]
# ### FUNCTIONS

# %% [markdown]
# In order to build a functionality that performs walk-forward validation in order to assess different hyperparameters, several functions will be constructed.

# %% [markdown]
# #### Fit & Forecast

# %% [markdown]
# The function below will fit a SARIMA model and perform a 1-step forecasting.

# %%
def sarima_forecast (history, config):
    order, sorder, trend = config
    # Define model
    model = SARIMAX(history,
                    order=order,
                    seasonal_order=sorder,
                    trend=trend,
                    enforce_stationarity=False,
                    enforce_invertibility=False
                    )
    # Fit model
    print('Fitting model...')
    model_fit = model.fit(disp=False, maxiter=5000)
    # Make a 1-step forecast
    print('Making prediction...')
    yhat = model_fit.predict(len(history), len(history)+1)
    print('Prediction:', yhat[0])
    return yhat[0]

# %% [markdown]
# #### Train/Test Split

# %%
def train_test_split (data, n_test):
    print('train_test_split...')
    return data[:-n_test], data[-n_test:]

# %% [markdown]
# #### RMSE

# %% [markdown]
# In order to select the hyperparameters yielding the best-performing model, we need a measure of model performance. Root of meen squared error (RMSE) will be used.

# %%
def measure_rmse (actual, predicted):
    print('Calculating error...')
    return sqrt(mean_squared_error(actual, predicted))

# %% [markdown]
# #### Walk-Forward Validation

# %% [markdown]
# Validation function. The idea is to obtain a number of time points to test on (the last time points). For each time point, the model will be trained on the preceding time points and then the current time point will be predicted. The next iteration will move on to the subsequent time point and so on.

# %%
def walk_forward_validation (data, n_test, cfg):
    predictions = list()
    # split dataset
    train, test = train_test_split (data, n_test)
    # seed history with training data
    history = [x for x in train]
    # step over each time-step in the test set
    for i in range (len(test)):
        print(f'Making predictions number {i}')
        # fit model and make forecast for history
        yhat = sarima_forecast(history, cfg)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for next iteration
        history.append(test[i])
    # estimate prediction error
    error = measure_rmse(test, predictions)
    return error

# %% [markdown]
# #### Score

# %% [markdown]
# The function below will serve as a wrapper intended to capture all warning and potential error messages. It is essentially a wrapper for `walk_forward_validation`.

# %%
# score a model, return None if failure
def score_model(data, n_test, cfg, debug=False):
    result = None
    # convert config to a key
    key = str(cfg)
    # show warning and fail on exception if debugging
    if debug:
        result = walk_forward_validation(data, n_test, cfg)
    else:
        # one failure during model validation suggest unstable config
        try:
            # never show warning when grid searching
            result = walk_forward_validation(data, n_test, cfg)
        except Exception as e:
            print (f'An error occured: {e}',)
            result = None
        print('\n------------', (key, result), '\n------------\n\n')
    return (key, result)

# %% [markdown]
# #### Grid Search

# %% [markdown]
# Finally, this function will loop over all hyperparameter values to assess model performance. Note that this function can be adapted to apply multi-processing to speed up the grid search.

# %%
def grid_search(data, cfg_list, n_test):
    scores = []
    for cfg in cfg_list:
        print(cfg)
        score = score_model(data, n_test, cfg)
        scores.append(score)
    scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
    # sort configs by error, asc
    scores.sort(key=lambda tup: tup[1])
    return scores

# %% [markdown]
# #### Define hyperparameters

# %% [markdown]
# The function below will define lists of hyperparameters to be used for the grid search. These hyperparameters are alluded to [above](#parameters).

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Parameters!</b> The various values for the hyperparametes are declared directly into the function before the different configurations are extracted. <u>The function can be enhanced by including parameters where one can specify the vaious parameters as arguments when calling the function.</u>
# </div>

# %%
# Create SARIMA configurations to be tested
def sarima_configs(seasonal=[5, 20]): # seasonality of week and year
    models = list()
    # define config lists
    p_params = [1, 2] # 1 discovered from PACPlot
    d_params = [0] # 0 from using days
    q_params = [0, 1, 2] # Moving average - nothing or last 2 months
    t_params = ['ct','c', 'n'] # The trend is non of these but try
    P_params = [0, 1, 2, 4] # Seasonal autoregressive order (weekly)
    D_params = [0] # Seasonal differencing
    Q_params = [0, 1] # Seasonal adjustment
    m_params = seasonal # Seasonality
    # Create config instances:
    for p in p_params:
        for d in d_params:
            for q in q_params:
                for t in t_params:
                    for P in P_params:
                        for D in D_params:
                            for Q in Q_params:
                                for m in m_params:
                                    cfg=[(p, d, q), (P, D, Q, m), t]
                                    models.append(cfg)
    return models

# %% [markdown]
# ### Grid Search

# %% [markdown]
# The functions will now be used to perform a grid search for the vaious configurations for the time series model hyperparameters.
#
#   2 weeks (**10 time points** or 2 cycles) will be used for as validation points.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>NB!:</b> Note that the optimized model will be tested on completely new incoming data. <i>In this context, there is not allocated test dataset.</i>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Since the model is quite resource-heavy, the actual run will be done in Terminal. Essentially, the script <b><u> Stock_1_SARIMA.py </u></b> only incorporates the code for this module.
# </div>

# %%
# transform data
data = list(df['close'])
# data split
n_test = 10
# Generating hyperparameter combinations
cfg_list = sarima_configs()
print('Total number of configurations to test', len(cfg_list))
# grid search
scores = grid_search(data, cfg_list, n_test)
# List top 3 configurations:
for cfg, error in scores[:3]:
    print (cfg, error)

# %% [markdown]
# ## Final Model (SARIMA)

# %% [markdown]
# The best configuration from above will be used to build a time series SARIMA model on the complete data set. As mentioned earlier, the test data will be new, incoming data points.

# %% [markdown]
# First, the model will be trained on the training data and predictions will be made on the training data and a validation set as done during the optimization phase. Then, the model will be trained using the optimal hyperparameter as determined by the grid search in `Stock_1_SARIMA.py` and as described above.
#
# The output of the grid search is:
# - \[(1, 0, 1), (1, 0, 1, 5), 'ct'] ---- 0.046184592185630854
# - \[(1, 0, 1), (2, 0, 1, 5), 'ct'] ---- 0.04874532046906347
# - \[(2, 0, 2), (1, 0, 1, 5), 'ct'] ---- 0.05035231078342537

# %% [markdown]
# **Model 1**
# - `p` = 1
# - `d` = 0
# - `q` = 1
# - `P` = 1
# - `D` = 0
# - `Q` = 1
# - `seasonality` = 5
# - `trend` = constant & linear
#
# **Model 2**
# - `p` = 1
# - `d` = 0
# - `q` = 1
# - `P` = 2
# - `D` = 0
# - `Q` = 1
# - `seasonality` = 5
# - `trend` = constant & linear
#
# **Model 3**
# - `p` = 2
# - `d` = 0
# - `q` = 2
# - `P` = 1
# - `D` = 0
# - `Q` = 1
# - `seasonality` = 5
# - `trend` = constant & linear

# %% [markdown]
# ### Model 1 SARIMA

# %%
## Predict validation set

# Define parameters:
p = 1
d = 0
q = 1
P = 1
D = 0
Q = 1
S = 5
t = 'ct'
cfg=[(p, d, q), (P, D, Q, S), t]

# Leave 10 time points for validation
n_test=10
# List to hold predictions
predictions = list()
# split dataset
train, test = train_test_split (list(df['close']), n_test)
# seed history with training data
history = [x for x in train]
# step over each time-step in the test set
for i in range (len(test)):
    print(f'Making predictions number {i}')
    # fit model and make forecast for history
    yhat = sarima_forecast(history, cfg)
    # store forecast in list of predictions
    predictions.append(yhat)
    # add actual observation to history for next iteration
    history.append(test[i])
# Out:
# train_test_split...
# Making predictions number 0
# Fitting model...
# C:\Users\Admin\anaconda3\envs\time_series\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Making prediction...
# Prediction: 2.2518897314056634
# Making predictions number 1
# Fitting model...
# Making prediction...
# Prediction: 2.202163676711301
# Making predictions number 2
# Fitting model...
# Making prediction...
# Prediction: 2.1337472848701
# Making predictions number 3
# Fitting model...
# Making prediction...
# Prediction: 2.1356457611215856
# Making predictions number 4
# Fitting model...
# Making prediction...
# Prediction: 2.095490690736746
# Making predictions number 5
# Fitting model...
# ...

# %%
## Predict training set

# Define parameters:
p = 1
d = 0
q = 1
P = 1
D = 0
Q = 1
S = 5
t = 'ct'
order = [p, d, q]
sorder = [P, D, Q, S]

# Obtain a train set as before
train, test = train_test_split (list(df['close']), n_test)
history = [x for x in train]
# Construct model with best parameters
model = SARIMAX(history,
                    order=order,
                    seasonal_order=sorder,
                    trend=t,
                    enforce_stationarity=False,
                    enforce_invertibility=False
                    )
# Fit model
model_fit = model.fit(disp=False, maxiter=5000)
# Make predictions on the training data
predictions_train = model_fit.get_prediction(1, len(train)+1).predicted_mean
# Out:
# train_test_split...
# C:\Users\Admin\anaconda3\envs\time_series\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# Now we plot the actual train and test data, as well as the predicted train and test data.

# %%
# Obtain dates for each set
x_ = list(df.index)
x_train = x_[:(len(predictions_train)+1)]
x_valid = x_[-n_test:]

# Create a subplot with a rangeslider
fig = make_subplots(rows=1, 
                    cols=1,
                    shared_xaxes=True, 
                    vertical_spacing=0.02, 
                    subplot_titles=("Actual vs Predicted Values at Close"))

# Add traces for each line
fig.add_trace(go.Scatter(x=x_, y=df['close'], opacity = 1.0,
                         mode='lines', 
                         name='Actual', line=dict(color='green')))
fig.add_trace(go.Scatter(x=x_valid, y=predictions, opacity = 0.3,
                         mode='lines', 
                         name='Predicted_validation', line=dict(color='red')))
fig.add_trace(go.Scatter(x=x_train, y=predictions_train, opacity = 0.3,
                         mode='lines', 
                         name='Predicted_training', line=dict(color='blue')))

# Set the layout properties
fig.update_layout(title='Multiple Lines with Range Slider',
                  xaxis_title='Date',
                  yaxis_title='Values',
                  xaxis_rangeslider_visible=True)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="122adbdd-26e9-43a3-ad80-b81af1378ca6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("122adbdd-26e9-43a3-ad80-b81af1378ca6")) {                    Plotly.newPlot(                        "122adbdd-26e9-43a3-ad80-b81af1378ca6",                        [{"line":{"color":"green"},"mode":"lines","name":"Actual","opacity":1.0,"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00
# ...

# %%
# Repeat for the last 20 data points only

# Obtain dates for each set
x_ = list(df.index)[-20:]
#x_train = x_[-20:-10]
x_valid = x_[-n_test:]

# Create a subplot with a rangeslider
fig = make_subplots(rows=1, 
                    cols=1,
                    shared_xaxes=True, 
                    vertical_spacing=0.02, 
                    subplot_titles=("Actual vs Predicted Values at Close"))

# Add traces for each line
fig.add_trace(go.Scatter(x=x_, y=df['close'][-20:], opacity = 1.0,
                         mode='lines', 
                         name='Actual', line=dict(color='green')))
fig.add_trace(go.Scatter(x=x_valid, y=predictions, opacity = 0.5,
                         mode='lines', 
                         name='Predicted_validation', line=dict(color='red')))
#fig.add_trace(go.Scatter(x=x_train, y=predictions_train[-20:], opacity = 0.5,
#                         mode='lines', 
#                         name='Predicted_training', line=dict(color='blue')))

# Set the layout properties
fig.update_layout(title='Actual vs Predicted Values at Close',
                  xaxis_title='Date',
                  yaxis_title='Values',
                  xaxis_rangeslider_visible=True)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="417774e1-8a91-4304-a636-5f290508c62b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("417774e1-8a91-4304-a636-5f290508c62b")) {                    Plotly.newPlot(                        "417774e1-8a91-4304-a636-5f290508c62b",                        [{"line":{"color":"green"},"mode":"lines","name":"Actual","opacity":1.0,"x":["2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00
# ...

# %% [markdown]
# ### Model 2 SARIMA

# %%
## Predict validation set

# Define parameters:
p = 1
d = 0
q = 1
P = 2
D = 0
Q = 1
S = 5
t = 'ct'
cfg=[(p, d, q), (P, D, Q, S), t]

# Leave 10 time points for validation
n_test=10
# List to hold predictions
predictions = list()
# split dataset
train, test = train_test_split (list(df['close']), n_test)
# seed history with training data
history = [x for x in train]
# step over each time-step in the test set
for i in range (len(test)):
    print(f'Making predictions number {i}')
    # fit model and make forecast for history
    yhat = sarima_forecast(history, cfg)
    # store forecast in list of predictions
    predictions.append(yhat)
    # add actual observation to history for next iteration
    history.append(test[i])
# Out:
# train_test_split...
# Making predictions number 0
# Fitting model...
# Making prediction...
# Prediction: 2.247925972387523
# Making predictions number 1
# Fitting model...
# Making prediction...
# Prediction: 2.2293342325310137
# Making predictions number 2
# Fitting model...
# Making prediction...
# Prediction: 2.166298252314701
# Making predictions number 3
# Fitting model...
# Making prediction...
# Prediction: 2.128327451775151
# Making predictions number 4
# Fitting model...
# Making prediction...
# Prediction: 2.066861276388232
# Making predictions number 5
# Fitting model...
# Making prediction...
# Prediction: 2.195440812511233
# Making predictions number 6
# Fitting model...
# Making prediction...
# Prediction: 2.1641607442278152
# Making predictions number 7
# Fitting model...
# Making prediction...
# Prediction: 2.0994693677262193
# Making predictions number 8
# Fitting model...
# Making prediction...
# Prediction: 1.9838702361359624
# Making predictions number 9
# ...

# %%
## Predict training set

# Define parameters:
p = 1
d = 0
q = 1
P = 1
D = 0
Q = 1
S = 5
t = 'ct'
order = [p, d, q]
sorder = [P, D, Q, S]

# Obtain a train set as before
train, test = train_test_split (list(df['close']), n_test)
history = [x for x in train]
# Construct model with best parameters
model = SARIMAX(history,
                    order=order,
                    seasonal_order=sorder,
                    trend=t,
                    enforce_stationarity=False,
                    enforce_invertibility=False
                    )
# Fit model
model_fit = model.fit(disp=False, maxiter=5000)
# Make predictions on the training data
predictions_train = model_fit.get_prediction(1, len(train)+1).predicted_mean
# Out:
# train_test_split...
# C:\Users\Admin\anaconda3\envs\time_series\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# Now we plot the actual train and test data, as well as the predicted train and test data.

# %%
# Repeat for the last 20 data points only

# Obtain dates for each set
x_ = list(df.index)[-20:]
#x_train = x_[-20:-10]
x_valid = x_[-n_test:]

# Create a subplot with a rangeslider
fig = make_subplots(rows=1, 
                    cols=1,
                    shared_xaxes=True, 
                    vertical_spacing=0.02, 
                    subplot_titles=("Actual vs Predicted Values at Close"))

# Add traces for each line
fig.add_trace(go.Scatter(x=x_, y=df['close'][-20:], opacity = 1.0,
                         mode='lines', 
                         name='Actual', line=dict(color='green')))
fig.add_trace(go.Scatter(x=x_valid, y=predictions, opacity = 1.0,
                         mode='lines', 
                         name='Predicted_validation', line=dict(color='red')))
#fig.add_trace(go.Scatter(x=x_train, y=predictions_train[-20:], opacity = 0.5,
#                         mode='lines', 
#                         name='Predicted_training', line=dict(color='blue')))

# Set the layout properties
fig.update_layout(title='Actual vs Predicted Values at Close',
                  xaxis_title='Date',
                  yaxis_title='Values',
                  xaxis_rangeslider_visible=True)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="87295ebf-6691-4627-bb41-961c3df0708a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87295ebf-6691-4627-bb41-961c3df0708a")) {                    Plotly.newPlot(                        "87295ebf-6691-4627-bb41-961c3df0708a",                        [{"line":{"color":"green"},"mode":"lines","name":"Actual","opacity":1.0,"x":["2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00
# ...

# %% [markdown]
# ### Model 3 SARIMA

# %%
## Predict validation set
[(2, 0, 2), (1, 0, 1, 5), 'ct']
# Define parameters:
p = 2
d = 0
q = 2
P = 1
D = 0
Q = 1
S = 5
t = 'ct'
cfg=[(p, d, q), (P, D, Q, S), t]

# Leave 10 time points for validation
n_test=10
# List to hold predictions
predictions = list()
# split dataset
train, test = train_test_split (list(df['close']), n_test)
# seed history with training data
history = [x for x in train]
# step over each time-step in the test set
for i in range (len(test)):
    print(f'Making predictions number {i}')
    # fit model and make forecast for history
    yhat = sarima_forecast(history, cfg)
    # store forecast in list of predictions
    predictions.append(yhat)
    # add actual observation to history for next iteration
    history.append(test[i])
# Out:
# train_test_split...
# Making predictions number 0
# Fitting model...
# Making prediction...
# Prediction: 2.234316898940677
# Making predictions number 1
# Fitting model...
# Making prediction...
# Prediction: 2.2284385831948
# Making predictions number 2
# Fitting model...
# Making prediction...
# Prediction: 2.1336625652721315
# Making predictions number 3
# Fitting model...
# C:\Users\Admin\anaconda3\envs\time_series\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# Making prediction...
# Prediction: 2.119051661530699
# Making predictions number 4
# Fitting model...
# Making prediction...
# Prediction: 2.0708474938472774
# Making predictions number 5
# Fitting model...
# Making prediction...
# Prediction: 2.129510652985107
# Making predictions number 6
# Fitting model...
# Making prediction...
# Prediction: 2.1594800310131657
# Making predictions number 7
# Fitting model...
# ...

# %%
## Predict training set

# Define parameters:
p = 1
d = 0
q = 1
P = 1
D = 0
Q = 1
S = 5
t = 'ct'
order = [p, d, q]
sorder = [P, D, Q, S]

# Obtain a train set as before
train, test = train_test_split (list(df['close']), n_test)
history = [x for x in train]
# Construct model with best parameters
model = SARIMAX(history,
                    order=order,
                    seasonal_order=sorder,
                    trend=t,
                    enforce_stationarity=False,
                    enforce_invertibility=False
                    )
# Fit model
model_fit = model.fit(disp=False, maxiter=5000)
# Make predictions on the training data
predictions_train = model_fit.get_prediction(1, len(train)+1).predicted_mean
# Out:
# train_test_split...
# C:\Users\Admin\anaconda3\envs\time_series\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# Now we plot the actual train and test data, as well as the predicted train and test data.

# %%
# Repeat for the last 20 data points only

# Obtain dates for each set
x_ = list(df.index)[-20:]
#x_train = x_[-20:-10]
x_valid = x_[-n_test:]

# Create a subplot with a rangeslider
fig = make_subplots(rows=1, 
                    cols=1,
                    shared_xaxes=True, 
                    vertical_spacing=0.02, 
                    subplot_titles=("Actual vs Predicted Values at Close"))

# Add traces for each line
fig.add_trace(go.Scatter(x=x_, y=df['close'][-20:], opacity = 1.0,
                         mode='lines', 
                         name='Actual', line=dict(color='green')))
fig.add_trace(go.Scatter(x=x_valid, y=predictions, opacity = 1.0,
                         mode='lines', 
                         name='Predicted_validation', line=dict(color='red')))
#fig.add_trace(go.Scatter(x=x_train, y=predictions_train[-20:], opacity = 0.5,
#                         mode='lines', 
#                         name='Predicted_training', line=dict(color='blue')))

# Set the layout properties
fig.update_layout(title='Actual vs Predicted Values at Close',
                  xaxis_title='Date',
                  yaxis_title='Values',
                  xaxis_rangeslider_visible=True)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="b7309b96-a848-4361-8644-4233fd595284" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7309b96-a848-4361-8644-4233fd595284")) {                    Plotly.newPlot(                        "b7309b96-a848-4361-8644-4233fd595284",                        [{"line":{"color":"green"},"mode":"lines","name":"Actual","opacity":1.0,"x":["2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00
# ...

# %% [markdown]
# ---
# The trends seem overall good, but there appears to be a lag of 1 day. Let us try to modify `p` and `P` values to determine if the problem will be solved.

# %% [markdown]
# ### MODIFIED Model 1 SARIMA

# %%
## Predict validation set

# Define parameters:
p = 0
d = 0
q = 1
P = 1
D = 0
Q = 1
S = 5
t = 'ct'
cfg=[(p, d, q), (P, D, Q, S), t]

# Leave 10 time points for validation
n_test=10
# List to hold predictions
predictions = list()
# split dataset
train, test = train_test_split (list(df['close']), n_test)
# seed history with training data
history = [x for x in train]
# step over each time-step in the test set
for i in range (len(test)):
    print(f'Making predictions number {i}')
    # fit model and make forecast for history
    yhat = sarima_forecast(history, cfg)
    # store forecast in list of predictions
    predictions.append(yhat)
    # add actual observation to history for next iteration
    history.append(test[i])
# Out:
# train_test_split...
# Making predictions number 0
# Fitting model...
# Making prediction...
# Prediction: 2.532973531529806
# Making predictions number 1
# Fitting model...
# Making prediction...
# Prediction: 2.0983644575266824
# Making predictions number 2
# Fitting model...
# Making prediction...
# Prediction: 2.396756759770377
# Making predictions number 3
# Fitting model...
# Making prediction...
# Prediction: 2.107071938016087
# Making predictions number 4
# Fitting model...
# Making prediction...
# Prediction: 2.2080072454051156
# Making predictions number 5
# Fitting model...
# Making prediction...
# Prediction: 2.2034805436171054
# Making predictions number 6
# Fitting model...
# Making prediction...
# Prediction: 2.1516165483567606
# Making predictions number 7
# Fitting model...
# Making prediction...
# Prediction: 2.145509428633728
# Making predictions number 8
# Fitting model...
# Making prediction...
# Prediction: 1.9985919174762707
# Making predictions number 9
# ...

# %% [markdown]
# Now we plot the actual train and test data, as well as the predicted train and test data.

# %%
# Obtain dates for each set
x_ = list(df.index)
x_train = x_[:(len(predictions_train)+1)]
x_valid = x_[-n_test:]

# Create a subplot with a rangeslider
fig = make_subplots(rows=1, 
                    cols=1,
                    shared_xaxes=True, 
                    vertical_spacing=0.02, 
                    subplot_titles=("Actual vs Predicted Values at Close"))

# Add traces for each line
fig.add_trace(go.Scatter(x=x_, y=df['close'], opacity = 1.0,
                         mode='lines', 
                         name='Actual', line=dict(color='green')))
fig.add_trace(go.Scatter(x=x_valid, y=predictions, opacity = 0.3,
                         mode='lines', 
                         name='Predicted_validation', line=dict(color='red')))
fig.add_trace(go.Scatter(x=x_train, y=predictions_train, opacity = 0.3,
                         mode='lines', 
                         name='Predicted_training', line=dict(color='blue')))

# Set the layout properties
fig.update_layout(title='Multiple Lines with Range Slider',
                  xaxis_title='Date',
                  yaxis_title='Values',
                  xaxis_rangeslider_visible=True)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="59440d2d-bf09-43b2-b8f3-999dcda6c5df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59440d2d-bf09-43b2-b8f3-999dcda6c5df")) {                    Plotly.newPlot(                        "59440d2d-bf09-43b2-b8f3-999dcda6c5df",                        [{"line":{"color":"green"},"mode":"lines","name":"Actual","opacity":1.0,"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00
# ...

# %%
# Repeat for the last 20 data points only

# Obtain dates for each set
x_ = list(df.index)[-20:]
#x_train = x_[-20:-10]
x_valid = x_[-n_test:]

# Create a subplot with a rangeslider
fig = make_subplots(rows=1, 
                    cols=1,
                    shared_xaxes=True, 
                    vertical_spacing=0.02, 
                    subplot_titles=("Actual vs Predicted Values at Close"))

# Add traces for each line
fig.add_trace(go.Scatter(x=x_, y=df['close'][-20:], opacity = 1.0,
                         mode='lines', 
                         name='Actual', line=dict(color='green')))
fig.add_trace(go.Scatter(x=x_valid, y=predictions, opacity = 0.5,
                         mode='lines', 
                         name='Predicted_validation', line=dict(color='red')))
#fig.add_trace(go.Scatter(x=x_train, y=predictions_train[-20:], opacity = 0.5,
#                         mode='lines', 
#                         name='Predicted_training', line=dict(color='blue')))

# Set the layout properties
fig.update_layout(title='Actual vs Predicted Values at Close',
                  xaxis_title='Date',
                  yaxis_title='Values',
                  xaxis_rangeslider_visible=True)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="3aa69bd9-aa91-4248-8a56-ee7b072f1703" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3aa69bd9-aa91-4248-8a56-ee7b072f1703")) {                    Plotly.newPlot(                        "3aa69bd9-aa91-4248-8a56-ee7b072f1703",                        [{"line":{"color":"green"},"mode":"lines","name":"Actual","opacity":1.0,"x":["2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00","2023-07-31T00:00:00","2023-08-01T00:00:00","2023-08-02T00:00
# ...

# %% [markdown]
# It appears somewhat closer in some stretches compared to others.
# >Overall, a good strategy would be to combine all models to predict value/outcome(up vs down compared to previous day).
# ---

# %% [markdown]
# <div style="text-align: right"> END of SARIMA MODELS </div>
# <div style="text-align: right"> Date: 2023-08-10 </div>
# <div style="text-align: right"> Author: Vassil Dimitrov </div>
