# %% [markdown]
# # Predicting Daily STOCK 1 Values at Market Close

# %% [markdown]
# ---
# <div style="text-align: right"> <b>AUTHOR</b>: Vassil Dimitrov, PhD </div>
# <div style="text-align: right"> <b>START DATE</b>: 2023-07-30 </div></br>
# <div style="text-align: right"><b>Contacts:</b></div>
# <div style="text-align: right">LinkedIn: <a href="https://www.linkedin.com/in/vassilDim">linkedin.com/in/vassilDim</a></div>
# <div style="text-align: right">email: vasssildimitrov@gmail.com</div>

# %% [markdown]
# Several models will be built based on the historical data for share values of *Stock 1* in order to predict future values (on a daily basis). More specifically, 3 models of increasing complexity will be considered constructed, optimized and tested:
# 1. Time series with `SARIMAX`
# 2. Time series with `TBATS`, which can capture more than 1 seasonal trends
# 3. LSTM RNN deep networks

# %% [markdown]
# **OUTLINE**
#
# 1. Module 1 - **LOAD & CLEAN DATA**
#     - read in the data
#     - explore data
#     - deal with missing and duplicated values
#
# 2. Module 2 - **EXPLORATORY DATA ANALYSIS**
#     - visualize the data
#     - subset the data
#     - comment on any trends
# 3. Module 3 - **PREDICTION WITH SARIMAX**
#     - optimize hyperparameters
#     - fit optimal model
#     - assess performance daily
# 4. Module 4 - **PREDICTION WITH TBATS**
#     - optimize hyperparameters
#     - fit optimal model
#     - assess performance daily
# 5. Module 4 - **PREDICTION WITH LSTM RNN DEEP NETS**
#     - optimize hyperparameters and network architecture
#     - fit optimal model
#     - assess performance daily
#
# ---

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX

# plotting
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## MODULE 1 -- Load & Clean Data

# %%
dat = pd.read_csv('MacroTrends_Data_Download_FCEL.csv', skiprows=14)
display(dat.head())
# Out:
#          date      open      high       low     close  volume
# 0  1997-02-27  288.0002  288.0002  282.0002  285.1202     194
# 1  1997-02-28  282.0002  285.1202  282.0002  285.1202      25
# 2  1997-03-03  288.0002  288.0002  279.1202  279.1202     142
# 3  1997-03-04  278.8802  278.8802  278.8802  278.8802       0
# 4  1997-03-05  282.0002  285.1202  282.0002  285.1202     136

# %% [markdown]
# One can see that the data has several variables for which it keeps track: date of record `date`, value at opening `open`, value at closing `close`, highest daily value `high`, lowest daily value `low` and daily volume of transactions `volume`. Intuitively, `open` and `close` should be quite correlated, which will be shown in **Module 2 - EDA**.

# %% [markdown]
# Several steps will be taken to make sure that the data is ready for modelling:
# 1. Appropriate column names
# 2. Appropriate data types for each feature/column
#     - numeric
#     - datetime
# 3. No missing values
#     - detect missing values and impute
# 4. No duplications

# %%
dat.rename(columns = lambda x: x.strip(), inplace=True)
# Convert to datetime
dat['date'] = pd.to_datetime(dat['date'])
print('Feature types after cleaning:\n', dat.dtypes, '\n--------------------\n')
df = dat
# Set index as date
df.set_index('date', inplace=True)
print('Number of null values for unmodified data:\n', df.isna().sum(),'\n--------------------\n')
# Check timespan
first_day = df.index.min()
last_day = df.index.max()
# obtain full range
full_range = pd.date_range (start=first_day, end=last_day, freq='B')
# How many missing business days?
print(f'There are a total of {len(full_range.difference(df.index))} missing business days.\n')
print('The missing business days will be imputed in a forward-fill fashion.\n')
# shows that nulls are across rows and where they are
df_clean = df.reindex(full_range)
print('Null values:\n', df_clean.isna().sum())
sns.heatmap(df_clean.isna(), vmin=0, vmax=1)
plt.title('Missing values for original data')
plt.show()
# Forward fill to impute missing values
df_clean = df_clean.fillna(method='ffill')
# shows that nulls are across rows and where they are
# shows that nulls are across rows and where they are
sns.heatmap(df_clean.isna(), vmin=0, vmax=1)
plt.title('Missing values for imputed data')
plt.show()
# Out:
# Feature types after cleaning:
#  date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# dtype: object
# --------------------
#
# Number of null values for unmodified data:
#  open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# --------------------
#
# There are a total of 244 missing business days.
#
# The missing business days will be imputed in a forward-fill fashion.
#
# Null values:
#  open      244
# high      244
# low       244
# close     244
# volume    244
# dtype: int64

# %% [markdown]
# We can observe that all the features are in numeric format and the few null values present in the dataset were successfully imputed.
#
# ---

# %% [markdown]
# ## MODULE 2 -- EXPLORATORY DATA ANALYSIS

# %% [markdown]
# The first step is to simply plot the values for `close` and `open` in order to be able to zero-in on any obvious trends.

# %% [markdown]
# ### The Entire Data (Stock 1)

# %%
# Extract data for close value (monthly average)
series_data = df_clean["close"]
# Obtain rolling average:
rolling_avg = series_data.rolling(window=6).mean()
# add lines for each column
fig = px.line(df_clean, 
              x=df_clean.index, 
              y=df_clean[['open','close']].columns
              )

# Add rolling average line:
ma_line = go.Scatter(x=rolling_avg.index,
                     y=rolling_avg.values, 
                     name='trend for close', 
                     line=dict(color='black', width=3))
fig.add_trace(ma_line)

# axis labels and title
fig.update_layout(
    yaxis_title="Value", 
    legend_title="", 
    title="Stock value at opening and closing for the entire history"
)

# activate slider
fig.update_xaxes(rangeslider_visible=True)

fig.show()
# Out:
# <div>                            <div id="0ecf4811-d415-40ac-90b9-9c765df44c5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ecf4811-d415-40ac-90b9-9c765df44c5e")) {                    Plotly.newPlot(                        "0ecf4811-d415-40ac-90b9-9c765df44c5e",                        [{"hovertemplate":"variable=open<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"open","showlegend":true,"x":["1997-02-27T00:00:00","1997-02-28T00:00:00","1997-03-03T00:00:00","1997-03-04T00:00:00","1997-03-05T00:00:00","1997-03-06T00:00:00","1997-03-07T00:00:00","1997-03-10T00:00:00","1997-03-11T00:00:00","1997-03-12T00:00:00","1997-03-13T00:00:00","1997
# ...

# %% [markdown]
# Below are the main points observed for the data:
# >Quite a lot of variability initially
# >The values seem to stabilize at ~2018
# >The `close` and `open` values appear to be quite correlated. Therefore one could focus exclusively on `close` for modelling.

# %% [markdown]
# ### Data Starting At 2020 (Stock 1)

# %%
df_clean_2020 = df_clean.loc[df_clean.index >= "2020-01-01", ["open","close","volume"]]
# Extract data for close value (monthly average)
series_data = df_clean_2020["close"]
# Obtain rolling average:
rolling_avg = series_data.rolling(window=6).mean()
# add lines for each column
fig = px.line(df_clean_2020, 
              x=df_clean_2020.index, 
              y=df_clean_2020[['open','close']].columns
              )

# Add rolling average line:
ma_line = go.Scatter(x=rolling_avg.index,
                     y=rolling_avg.values, 
                     name='trend for close', 
                     line=dict(color='black', width=3))
fig.add_trace(ma_line)

# axis labels and title
fig.update_layout(
    yaxis_title="Value", 
    legend_title="", 
    title="Stock value at opening and closing (2020 onwards)"
)

# activate slider
fig.update_xaxes(rangeslider_visible=True)

fig.show()
# Out:
# <div>                            <div id="5d6f99f7-a285-4453-b76f-f1a7a7207bc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d6f99f7-a285-4453-b76f-f1a7a7207bc0")) {                    Plotly.newPlot(                        "5d6f99f7-a285-4453-b76f-f1a7a7207bc0",                        [{"hovertemplate":"variable=open<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"open","showlegend":true,"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020
# ...

# %% [markdown]
# >**Only data from 2020 onwards will be considered for downstream analysis.**

# %%
# Calculate correlation
corr_matrix = df_clean_2020.corr()
# Create a mask for upper triangle (including diagonal)
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
# Create a heatmap for variable correlation
plt.figure()
sns.heatmap(corr_matrix, 
            annot=True,
            mask=mask,
            cmap='coolwarm', fmt='.2f', vmin=-1)
plt.title('Variable Correlation')
plt.show()

# %% [markdown]
# The correlation plot above confirms that `open` and `close` values are virtually perfectly correlated and only one is needed for predicting the daily value of the shares (`close`).
#
# Let us quickly look at the distribution of the variables in the dataset.

# %%
# Plot the distribution of all features as histograms
# Create subplots for each column in df_clean_2020
fig, axes = plt.subplots(nrows=1, ncols=len(df_clean_2020.columns), figsize=(15, 6))
for i, col in enumerate(df_clean_2020.columns):
    df_clean_2020[col].plot(kind='hist', bins=25, ax=axes[i], title=col)

plt.tight_layout()
plt.show()

# %% [markdown]
# `volume`, `close`, and `open`are right-skewed. These values can be transformed by taking their log. This will make them more normally distributed, if one wished to fit a linear regression, which we will abstain from at the present moment.
#
#   Next, seasonality is determined by applying seasonal decomposition as plotted below

# %%
# Decompose time series for month
decomp_days = sm.tsa.seasonal_decompose(df_clean_2020['close'], model = 'additive')
# add the decomposition data
df_clean_2020["Trend"] = decomp_days.trend
df_clean_2020["Seasonal"] = decomp_days.seasonal
df_clean_2020["Residual"] = decomp_days.resid

# Plot trend, seasonal and residual components
cols = ["Trend", "Seasonal", "Residual"]
colors = ['blue', 'red', 'green']

for i, col in enumerate(cols):
    figa = go.Figure(go.Scatter(x=df_clean_2020.index, 
                                y=df_clean_2020[col], 
                                name=col, 
                                line=dict(color=colors[i])
                               ))
    # Update the layout of each figure to add a range slider
    figa.update_layout(xaxis=dict(rangeslider=dict(visible=True), type='date'), title=col)
    # Display figure
    figa.show()
    del figa
# Out:
# <div>                            <div id="bc595371-b5b8-4704-bed5-c902d2cbae13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc595371-b5b8-4704-bed5-c902d2cbae13")) {                    Plotly.newPlot(                        "bc595371-b5b8-4704-bed5-c902d2cbae13",                        [{"line":{"color":"blue"},"name":"Trend","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","202
# ...

# %% [markdown]
# Clearly, the data is static (residuals centred around 0) even though one can observe some heteroscedasticity (RESIDUALS plot).
# There is a bit of an oscilating trend in the TREND plot that remains after factoring out the seasonal component.
# Finally, there is a clear seasonality as illustrated by the SEASONAL plot.
# The model will be optimized so that it captures as much of the trend and seasonal components in making future predictions.

# %% [markdown]
# ## MODULE 3 -- TIME SERIES WITH SARIMAX

# %% [markdown]
# The parameters for fitting the time series model using *SARIMAX* is discussed in detail in `Stocks_1_SARIMA.ipynb` and the associated optimisation code provided in the `Stocks_1_SARIMA.py` script. Below, the performance of the optimal model will be assessed on the training data, the validation data (walk-forward validation) and on new daily data that is obtained after the model was trained.

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: right"> <b>AUTHOR</b>: Vassil Dimitrov, PhD </div>
# <div style="text-align: right"> <b>END DATE</b>: 2023-08-09 </div></br>
